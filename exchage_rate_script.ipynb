# %% [markdown]
# ### Как получать курсы валют

# %%
import requests

# %%
r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
r
# Out:
# <Response [200]>

# %%
r.json()['Valute']['AUD']['Value']
# Out:
# 54.3752
