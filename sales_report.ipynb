# %%
import requests

# %%
data = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

# %%
data.json()
# Out:
# {'Date': '2024-11-09T11:30:00+03:00',
#  'PreviousDate': '2024-11-08T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2024/11/08/daily_json.js',
#  'Timestamp': '2024-11-08T19:00:00+03:00',
#  'Valute': {'AUD': {'ID': 'R01010',
#    'NumCode': '036',
#    'CharCode': 'AUD',
#    'Nominal': 1,
#    'Name': 'Австралийский доллар',
#    'Value': 65.0984,
#    'Previous': 64.9437},
#   'AZN': {'ID': 'R01020A',
#    'NumCode': '944',
#    'CharCode': 'AZN',
#    'Nominal': 1,
#    'Name': 'Азербайджанский манат',
#    'Value': 57.5491,
#    'Previous': 57.6898},
#   'GBP': {'ID': 'R01035',
#    'NumCode': '826',
#    'CharCode': 'GBP',
#    'Nominal': 1,
#    'Name': 'Фунт стерлингов Соединенного королевства',
#    'Value': 127.1444,
#    'Previous': 126.4156},
#   'AMD': {'ID': 'R01060',
#    'NumCode': '051',
#    'CharCode': 'AMD',
#    'Nominal': 100,
#    'Name': 'Армянских драмов',
#    'Value': 25.2558,
#    'Previous': 25.3267},
#   'BYN': {'ID': 'R01090B',
# ...
